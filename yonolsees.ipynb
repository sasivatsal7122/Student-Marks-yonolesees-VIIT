# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading and visulazing the Data

# %%
dms = pd.read_excel("datasets/DMS.xlsx")
python = pd.read_excel("datasets/Programming Essentials in Python.xlsx")
se = pd.read_excel("datasets/Software Engineering.xlsx")
sds = pd.read_excel("datasets/SDS-2.xlsx")

# %%
dms.head(10)
# Out:
#   VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM  \
# 0                               PROGRAMME:    B Tech
# 1                           Course Code : 1000202100
# 2                                               S.No
# 3                                                NaN
# 4                                                NaN
# 5                                                  1
# 6                                                  2
# 7                                                  3
# 8                                                  4
# 9                                                  5
#
#    Unnamed: 1 Unnamed: 2                                      Unnamed: 3  \
# 0         NaN        NaN                                      YEAR :  II
# 1         NaN        NaN  Course Name : Discrete Mathematical Structures
# 2    Regd. No     PART-A                             PART-B (SUBJECTIVE)
# 3         NaN  OBJECTIVE                                        2  (10M)
# 4         NaN         6M                                               A
# 5  20L31A5401          5                                               5
# 6  20L31A5402          6                                               5
# 7  20L31A5403          4                                               5
# 8  20L31A5404          6                                               5
# 9  20L31A5405          2                                               5
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN  SEMESTER:         NaN
# 1        NaN        NaN        NaN        NaN         NaN        NaN
# 2        NaN        NaN        NaN        NaN         NaN        NaN
# 3        NaN        NaN  3   (10M)        NaN         NaN    4  (4M)
# 4          B          C          A          B           C          A
# 5          5        NaN          3          2         NaN          2
# 6          5        NaN          3          3         NaN          4
# 7          5        NaN          3          3         NaN          3
# 8          5        NaN          3          5         NaN          3
# 9          5        NaN          2          5         NaN          1
#
#   Unnamed: 10 Unnamed: 11   Unnamed: 12          Unnamed: 13
# 0           I      MID: 1        BRANCH              AI & DS
# 1         NaN         NaN  Date of Exam  2022-10-01 00:00:00
# 2         NaN         NaN         GRAND         Student sign
# 3         NaN       TOTAL         TOTAL                  NaN
# 4           B          24            18                  NaN
# 5         NaN          17            14                  NaN
# 6         NaN          20            16                  NaN
# 7         NaN          19            14                  NaN
# 8         NaN          21            17                  NaN
# 9         NaN          18            11                  NaN

# %%
python.head(10)
# Out:
#   VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM  \
# 0                               PROGRAMME:    B Tech
# 1                            Course Code :1005202104
# 2                                               S.No
# 3                                                NaN
# 4                                                NaN
# 5                                                  1
# 6                                                  2
# 7                                                  3
# 8                                                  4
# 9                                                  5
#
#    Unnamed: 1 Unnamed: 2                                      Unnamed: 3  \
# 0         NaN        NaN                                         YEAR :
# 1         NaN        NaN  Course Name : PROGRAMMING ESSENTIALS IN PYTHON
# 2    Regd. No     PART-A                             PART-B (SUBJECTIVE)
# 3         NaN  OBJECTIVE                                        2  (10M)
# 4         NaN         6M                                               A
# 5  20L31A5401          5                                               5
# 6  20L31A5402          6                                               5
# 7  20L31A5403          4                                               4
# 8  20L31A5404          6                                               5
# 9  20L31A5405          5                                               3
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN          2        NaN  SEMESTER:         NaN
# 1        NaN        NaN        NaN        NaN         NaN        NaN
# 2        NaN        NaN        NaN        NaN         NaN        NaN
# 3        NaN        NaN  3   (10M)        NaN         NaN    4  (4M)
# 4          B          C          A          B           C          A
# 5          4        NaN          3          2         NaN          3
# 6          4        NaN          5          5         NaN          4
# 7          4        NaN          4          3         NaN          4
# 8          4        NaN          5          5         NaN          3
# 9          4        NaN          0          4         NaN          4
#
#   Unnamed: 10 Unnamed: 11   Unnamed: 12          Unnamed: 13
# 0           1      MID: 1        BRANCH                AI&DS
# 1         NaN         NaN  Date of Exam  2022-12-18 00:00:00
# 2         NaN         NaN         GRAND         Student sign
# 3         NaN       TOTAL         TOTAL                  NaN
# 4           B          24            18                  NaN
# 5         NaN          17            14                  NaN
# 6         NaN          23            18                  NaN
# 7         NaN          19            14                  NaN
# 8         NaN          22            17                  NaN
# 9         NaN          15            13                  NaN

# %%
se.head(10)
# Out:
#   VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM  \
# 0                               PROGRAMME:    B Tech
# 1                            Course Code :1005202103
# 2                                               S.No
# 3                                                NaN
# 4                                                NaN
# 5                                                  1
# 6                                                  2
# 7                                                  3
# 8                                                  4
# 9                                                  5
#
#    Unnamed: 1 Unnamed: 2                         Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN                          YEAR : II        NaN
# 1         NaN        NaN  Course Name :SOFTWARE ENGINEERING        NaN
# 2    Regd. No     PART-A                PART-B (SUBJECTIVE)        NaN
# 3         NaN  OBJECTIVE                           2  (10M)        NaN
# 4         NaN         6M                                  A          B
# 5  20L31A5401          2                                  4          4
# 6  20L31A5402          3                                  5          4
# 7  20L31A5403          3                                  5          4
# 8  20L31A5404          3                                  4          4
# 9  20L31A5405          1                                  3        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN  SEMESTER:         NaN           I
# 1        NaN        NaN        NaN         NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN        NaN         NaN
# 3        NaN  3   (10M)        NaN         NaN    4  (4M)         NaN
# 4          C          A          B           C          A           B
# 5        NaN          1          1         NaN        NaN         NaN
# 6        NaN          5          5         NaN          4         NaN
# 7        NaN          5          4         NaN          3         NaN
# 8        NaN          5          5         NaN          4         NaN
# 9        NaN          4          5         NaN          0         NaN
#
#   Unnamed: 11   Unnamed: 12          Unnamed: 13
# 0      MID: 1        BRANCH                 AIDS
# 1         NaN  Date of Exam  2022-01-20 00:00:00
# 2         NaN         GRAND         Student sign
# 3       TOTAL         TOTAL                  NaN
# 4          24            18                  NaN
# 5          10             7                  NaN
# 6          23            15                  NaN
# 7          21            14                  NaN
# 8          22            14                  NaN
# 9          12             7                  NaN

# %%
sds.head(10)
# Out:
#   VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM  \
# 0                                                NaN
# 1                                                NaN
# 2                                               S.no
# 3                                                  1
# 4                                                  2
# 5                                                  3
# 6                                                  4
# 7                                                  5
# 8                                                  6
# 9                                                  7
#
#    Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0         NaN        NaN         NaN    BRANCH:      AI&DS         NaN
# 1         NaN        NaN         NaN        NaN        NaN         NaN
# 2    Regd. No  1.12.2021  22.12.2021        NaN        NaN         NaN
# 3  20L31A5401          8           8        NaN        NaN         NaN
# 4  20L31A5402          9          10        NaN        NaN         NaN
# 5  20L31A5403         10          10        NaN        NaN         NaN
# 6  20L31A5404         10          10        NaN        NaN         NaN
# 7  20L31A5405          6           4        NaN        NaN         NaN
# 8  20L31A5406          8           9        NaN        NaN         NaN
# 9  20L31A5407          A           6        NaN        NaN         NaN
#
#           Unnamed: 7
# 0  WEEKLY TEST MARKS
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN

# %%
python.drop(labels=[0,1,2], axis=0,inplace=True)
python.drop(["VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM",'Unnamed: 5','Unnamed: 8','Unnamed: 10','Unnamed: 13'], axis=1,inplace=True)

dms.drop(labels=[0,1,2], axis=0,inplace=True)
dms.drop(["VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM",'Unnamed: 5','Unnamed: 8','Unnamed: 10','Unnamed: 13'], axis=1,inplace=True)

se.drop(labels=[0,1,2], axis=0,inplace=True)
se.drop(["VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM",'Unnamed: 5','Unnamed: 8','Unnamed: 10','Unnamed: 13'], axis=1,inplace=True)

# sds.drop(labels=[0,1,2], axis=0,inplace=True)
# sds.drop(["VIGNAN'S INSTITUTE OF INFORMATION TECHNOLOGY (AUTONOMOUS) : VISAKHAPATNAM",'Unnamed: 5','Unnamed: 8','Unnamed: 10','Unnamed: 13'], axis=1,inplace=True)
# sds.reset_index()

# %%
python.head(10)
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 6 Unnamed: 7  \
# 3          NaN  OBJECTIVE   2  (10M)        NaN  3   (10M)        NaN
# 4          NaN         6M          A          B          A          B
# 5   20L31A5401          5          5          4          3          2
# 6   20L31A5402          6          5          4          5          5
# 7   20L31A5403          4          4          4          4          3
# 8   20L31A5404          6          5          4          5          5
# 9   20L31A5405          5          3          4          0          4
# 10  20L31A5406          5          4          4          3          2
# 11  20L31A5407          2          3          0          2          0
# 12  20L31A5408          3          5          0          5          0
#
#    Unnamed: 9 Unnamed: 11 Unnamed: 12
# 3     4  (4M)       TOTAL       TOTAL
# 4           A          24          18
# 5           3          17          14
# 6           4          23          18
# 7           4          19          14
# 8           3          22          17
# 9           4          15          13
# 10          1          14          12
# 11          1           6           5
# 12          2          12           9

# %%
se.head(10)
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 6 Unnamed: 7  \
# 3          NaN  OBJECTIVE   2  (10M)        NaN  3   (10M)        NaN
# 4          NaN         6M          A          B          A          B
# 5   20L31A5401          2          4          4          1          1
# 6   20L31A5402          3          5          4          5          5
# 7   20L31A5403          3          5          4          5          4
# 8   20L31A5404          3          4          4          5          5
# 9   20L31A5405          1          3        NaN          4          5
# 10  20L31A5406          3          5          3          3          2
# 11  20L31A5407          2          5          3          5          5
# 12  20L31A5408          1          5          2          5          5
#
#    Unnamed: 9 Unnamed: 11 Unnamed: 12
# 3     4  (4M)       TOTAL       TOTAL
# 4           A          24          18
# 5         NaN          10           7
# 6           4          23          15
# 7           3          21          14
# 8           4          22          14
# 9           0          12           7
# 10          2          15          11
# 11          0          18          11
# 12          2          19          11

# %%
dms.head(10)
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 6 Unnamed: 7  \
# 3          NaN  OBJECTIVE   2  (10M)        NaN  3   (10M)        NaN
# 4          NaN         6M          A          B          A          B
# 5   20L31A5401          5          5          5          3          2
# 6   20L31A5402          6          5          5          3          3
# 7   20L31A5403          4          5          5          3          3
# 8   20L31A5404          6          5          5          3          5
# 9   20L31A5405          2          5          5          2          5
# 10  20L31A5406          2          5          2          1          1
# 11  20L31A5407          1          5          2          0          0
# 12  20L31A5408          0          3          1          0          0
#
#    Unnamed: 9 Unnamed: 11 Unnamed: 12
# 3     4  (4M)       TOTAL       TOTAL
# 4           A          24          18
# 5           2          17          14
# 6           4          20          16
# 7           3          19          14
# 8           3          21          17
# 9           1          18          11
# 10          1          10           7
# 11        NaN           7           5
# 12          0           4           2
